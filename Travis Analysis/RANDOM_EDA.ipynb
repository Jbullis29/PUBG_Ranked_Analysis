# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
df = pd.read_csv("match_samps.csv")
df2 = df.drop(["stats.name", "matchId", "assetsId", "matchType", "stats.deathType", "map", "stats.rank", "stats.playerId"], axis=1)
value_count = df2['gameMode'].value_counts()
df_value_counts = pd.DataFrame(value_count)
df_value_counts = df_value_counts.reset_index()
df_value_counts.columns = ['gameMode', 'num_games_played']
df3 = df2[df2['gameMode']=="solo"]
def f(row):
    if row['stats.winPlace'] <= 5:
        val = 1
    else:
        val = 0

    return val
df3['top_five'] = df.apply(f, axis=1)
df3
# Out:
# <ipython-input-3-4a7d3c1f6522>:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['top_five'] = df.apply(f, axis=1)
#        gameDuration gameMode  stats.DBNOs  stats.assists  stats.boosts  \
# 286            2214     solo          0.0            0.0           0.0
# 287            2214     solo          0.0            0.0           0.0
# 288            2214     solo          0.0            0.0           4.0
# 289            2214     solo          0.0            0.0           4.0
# 290            2214     solo          0.0            0.0           0.0
# ...             ...      ...          ...            ...           ...
# 20576          2150     solo          0.0            0.0           0.0
# ...

# %%
df3['stats.kills'].describe()
# Out:
# count    3829.000000
# mean        0.866806
# std         1.549773
# min         0.000000
# 25%         0.000000
# 50%         0.000000
# 75%         1.000000
# max        18.000000
# Name: stats.kills, dtype: float64

# %%
def f(row):
    if row['stats.kills'] >=10:
        val = '10+ Kills'
    elif row['stats.kills'] >=6:
        val = '6-10 Kills'
    elif row['stats.kills'] >=3:
        val = '3-5 Kills'
    elif row['stats.kills'] >=1:
        val = '1-2 Kills'
    else:
        val = '0 Kills'

    return val
df3['kill_catagories'] = df.apply(f, axis=1)
df3
# Out:
# <ipython-input-5-34bf4d46738f>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['kill_catagories'] = df.apply(f, axis=1)
#        gameDuration gameMode  stats.DBNOs  stats.assists  stats.boosts  \
# 286            2214     solo          0.0            0.0           0.0
# 287            2214     solo          0.0            0.0           0.0
# 288            2214     solo          0.0            0.0           4.0
# 289            2214     solo          0.0            0.0           4.0
# 290            2214     solo          0.0            0.0           0.0
# ...             ...      ...          ...            ...           ...
# 20576          2150     solo          0.0            0.0           0.0
# ...

# %%
# def w(row):
#     if row['stats.winPlace'] >=10:
#         val = row['stats.winPlace']/100
#     elif row['stats.winPlace'] >=1:
#         val = row['stats.winPlace']
#     else:
#         val = 0
#     return val
winPercent = []
for i in df3['stats.winPlace']:
    i = 100 - i 
    i = i/100
    winPercent.append(i)
df3['winPercent'] = winPercent
df4=df3.sort_values(by=['winPercent'])
df4.tail()
# Out:
# <ipython-input-6-89f6f949cca3>:14: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df3['winPercent'] = winPercent
#        gameDuration gameMode  stats.DBNOs  stats.assists  stats.boosts  \
# 18784          2097     solo          0.0            0.0           4.0
# 6375           2514     solo          0.0            0.0           7.0
# 15530          2382     solo          0.0            0.0           9.0
# 10717          2250     solo          0.0            0.0           9.0
# 4149           2016     solo          0.0            0.0           5.0
#
#        stats.damageDealt  stats.headshotKills  stats.heals  stats.killPlace  \
# 18784          299.99997                  1.0          2.0              9.0
# ...

# %%
sns.set_theme(style="whitegrid", palette="bright")
plt.figure(figsize=(8,6))
ax = sns.boxplot(x="kill_catagories",y='winPercent', data=df3, order=['0 Kills', '1-2 Kills', '3-5 Kills', '6-10 Kills', '10+ Kills'])

plt.savefig('DataTrav/boxplot.png')
