# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %%
df= pd.read_csv('../data/test_telemetry.csv')
df.head(10)
# Out:
# C:\Users\tbrid\anaconda3\lib\site-packages\IPython\core\interactiveshell.py:3146: DtypeWarning: Columns (1,3,21,40,42,43,63,64,65,66,68,69,70,197,198,203,205,209,211,218,219,220,221,223,225,226) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#    Unnamed: 0                                            MatchId  PingQuality  \
# 0           0  match.bro.official.console-13.console.squad-fp...          NaN
# 1           1                                                NaN          NaN
# 2           2                                                NaN          NaN
# 3           3                                                NaN          NaN
# 4           4                                                NaN          NaN
# 5           5                                                NaN          NaN
# 6           6                                                NaN          NaN
# ...

# %%
df['killer'].nunique()
# Out:
# 0
