# %%
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score
from sklearn.model_selection import train_test_split

# %%
rank_df = pd.read_csv('data/season_one_and_two_ranked_player_stats.csv')

# %%
rank_df.drop('Unnamed: 0', axis =1, inplace=True)
rank_df
# Out:
#                 name                                account_id   season  rank  \
# 0        Oilersfan74  account.166d81fc85534147b1b4bf2e537d5077  xbox-01     1
# 1        ALPHA NANOC  account.f396a20e56a94b4ba82b5f4eebd54861  xbox-02     1
# 2         XIISJagobo  account.55ff3a6b5c964172a677104edeb8f2ce  xbox-02     2
# 3       WyattEarpXXX  account.d6c2446f5a924e53bb74b286ca1cc9ed  xbox-01     2
# 4         XIISJagobo  account.55ff3a6b5c964172a677104edeb8f2ce  xbox-01     3
# ..               ...                                       ...      ...   ...
# 639  FredyMercsTeeth  account.4f81907a8ea44ed88dcd6456e36bbda5  xbox-01   496
# 640  DMaintenanceMan  account.1fa4256076144155b45f674956af82dc  xbox-01   497
# 641        celsorico  account.08c7062c36774f8abbfb60f6646113ba  xbox-01   498
# 642     JustPhilly69  account.931cf2e9ba90427b9a1662e7522ba1fa  xbox-01   499
# 643           Krayyz  account.75cfd210686243c8bc947fd244f000e4  xbox-01   500
#
#      assists  damageDealt  days  headshotKills  heals  kills  ...  \
# 0        258   496847.470   120            822   4492   4016  ...
# 1        205   444983.030   109            938   1700   4104  ...
# 2        404   701186.060   113           1246   6576   6081  ...
# 3        575   816185.700   111           1416   2160   6728  ...
# 4        404   701186.060   113           1246   6576   6081  ...
# ..       ...          ...   ...            ...    ...    ...  ...
# 639       99   162739.880    77            241   3165   1356  ...
# 640       75    90082.414   110            121   1026    728  ...
# 641       82   133021.270   112            185   1243    982  ...
# 642       65    92424.950   109            160    736    733  ...
# 643       74   133977.020   116            292   1673   1080  ...
#
#      roundMostKills  roundsPlayed  suicides  swimDistance  timeSurvived  \
# 0                11          4220       182    35318.7700     3551210.8
# 1                18          1015        13     4118.4077      911952.4
# 2                15          2312        69    29266.5760     2733672.2
# 3                22          1535        25     7953.7310     1779426.0
# 4                15          2312        69    29266.5760     2733672.2
# ..              ...           ...       ...           ...           ...
# 639               9          1487        28    13378.5090     1268191.5
# 640               8           826        41    18404.8160     1031776.2
# 641               6          1646        36    16255.1850     1358778.6
# 642               7           914        10    13168.5190     1093476.2
# 643               7          1138        36     8750.0630      998620.9
#
#      top10s  vehicleDestroys  walkDistance  weaponsAcquired  wins
# 0       743              116     4822258.0            20648    64
# 1       341               48     2043421.2             4859   135
# 2       940              187     4058920.8            14552   269
# 3       638               81     2811716.8             7530   220
# 4       940              187     4058920.8            14552   269
# ..      ...              ...           ...              ...   ...
# 639     165                4     1561471.5             8629    14
# 640     295               52     1235367.5             3882    19
# 641     241               18     1922162.0             8883     6
# 642     367                5     1524067.5             3940    50
# 643     179                5     2092038.8             4529    12
#
# [644 rows x 27 columns]

# %%
top_150 = rank_df[rank_df['rank']<=150]
x = top_150['rank'].values.reshape(-1,1)
y = top_150['roundsPlayed'].values.reshape(-1,1)
y
# Out:
# array([[4220],
#        [1015],
#        [2312],
#        [1535],
#        [2312],
#        [1683],
#        [ 683],
#        [4108],
#        [2241],
#        [2617],
#        [2387],
#        [1492],
#        [2522],
#        [1059],
#        [2257],
#        [2267],
#        [2862],
#        [2418],
#        [1896],
#        [1472],
#        [2554],
#        [1748],
#        [1921],
#        [2321],
#        [ 190],
#        [1924],
#        [2522],
#        [1729],
#        [1948],
#        [1335],
#        [2192],
#        [ 777],
#        [2554],
#        [2903],
#        [1046],
#        [ 932],
#        [2321],
#        [2555],
#        [2862],
#        [ 276],
#        [1577],
#        [1270],
#        [2352],
#        [ 725],
#        [ 709],
#        [2057],
#        [ 852],
#        [1614],
#        [2513],
#        [1656],
#        [2314],
#        [1948],
#        [1615],
#        [1907],
#        [2044],
#        [1619],
#        [1468],
#        [4220],
#        [4385],
#        [1383],
#        [2241],
#        [1335],
#        [1907],
#        [2565],
#        [4108],
#        [2124],
#        [1656],
#        [1182],
#        [1287],
#        [ 967],
#        [1458],
#        [ 713],
#        [1709],
#        [1479],
#        [2090],
#        [1395],
#        [ 960],
#        [1146],
#        [ 569],
#        [1326],
#        [ 889],
#        [2016],
#        [2184],
#        [2778],
#        [1683],
#        [1067],
#        [ 889],
#        [2184],
#        [1494],
#        [2312],
#        [ 958],
#        [ 989],
#        [1416],
#        [1958],
#        [1181],
#        [3357],
#        [1700],
#        [1936],
#        [1999],
#        [ 864],
#        [ 884],
#        [1015],
#        [1597],
#        [1331],
#        [1584],
#        [1518],
#        [1541],
#        [ 591],
#        [1647],
#        [ 826],
#        [2879],
#        [1541],
#        [ 351],
#        [1514],
#        [2797],
#        [ 865],
#        [  34],
#        [ 896],
#        [ 782],
#        [1615],
#        [ 771],
#        [ 748],
#        [1091],
#        [1240],
#        [ 484],
#        [2004],
#        [ 152],
#        [1188],
#        [1479],
#        [ 654],
#        [1067],
#        [ 313],
#        [ 992],
#        [ 155],
#        [2797],
#        [ 820],
#        [1721],
#        [1637],
#        [1219],
#        [1518],
#        [ 642],
#        [1176],
#        [ 372],
#        [1998],
#        [ 430],
#        [ 719],
#        [3085],
#        [2106],
#        [2227],
#        [1147],
#        [1197],
#        [ 539],
#        [ 530],
#        [ 905],
#        [1336],
#        [3085],
#        [1621],
#        [ 465],
#        [ 553],
#        [1096],
#        [ 797],
#        [1499],
#        [1086],
#        [1522],
#        [2617],
#        [   0],
#        [1864],
#        [1611],
#        [1248],
#        [ 767],
#        [ 863],
#        [1187],
#        [2624],
#        [ 629],
#        [1160],
#        [ 431],
#        [   0],
#        [1219],
#        [1386],
#        [1727],
#        [ 521],
#        [1213],
#        [ 265],
#        [1192],
#        [1445],
#        [ 667],
#        [1836],
#        [ 288],
#        [1577],
#        [ 138],
#        [1535],
#        [1391],
#        [ 653],
#        [ 985],
#        [ 907],
#        [2016],
#        [ 245],
#        [1678],
#        [ 872],
#        [1337],
#        [1156],
#        [1060],
#        [ 597],
#        [1559],
#        [ 234],
#        [2154],
#        [1983],
#        [ 757],
#        [1786],
#        [ 404],
#        [1066],
#        [ 853],
#        [1075],
#        [ 605],
#        [2257],
#        [1507],
#        [1205],
#        [1495],
#        [ 979],
#        [ 783],
#        [ 979],
#        [1266],
#        [ 938],
#        [ 976],
#        [1476],
#        [2361],
#        [1560],
#        [1386],
#        [1282],
#        [1062],
#        [ 994],
#        [ 894],
#        [1987],
#        [ 886],
#        [ 882],
#        [ 976],
#        [ 711],
#        [1136],
#        [1308],
#        [1274],
#        [2778],
#        [1828],
#        [ 893],
#        [ 824],
#        [1160],
#        [ 568],
#        [1371],
#        [ 588],
#        [1075],
#        [2415],
#        [ 189],
#        [1059],
#        [1553],
#        [ 769],
#        [ 423],
#        [1372],
#        [1477],
#        [ 706],
#        [ 207],
#        [2417],
#        [2227],
#        [ 428],
#        [1382],
#        [1017],
#        [ 493],
#        [2049],
#        [1187],
#        [ 558],
#        [ 746],
#        [1343],
#        [1569],
#        [1026],
#        [ 722],
#        [1256],
#        [2025],
#        [ 615],
#        [1700],
#        [1447],
#        [ 877],
#        [1018],
#        [1416],
#        [ 635],
#        [ 514],
#        [ 877],
#        [1692],
#        [1637],
#        [ 886],
#        [1663],
#        [1265],
#        [1846],
#        [ 806],
#        [ 918],
#        [2298],
#        [2406]], dtype=int64)

# %%
plt.scatter(x,y)

# %%
model = LinearRegression()
model.fit( x, y)
# Out:
# LinearRegression()

# %%
print('Weight coefficients: ', model.coef_)
print('y-axis intercept: ', model.intercept_)
x_min = np.array([[x.min()]])
x_max = np.array([[x.max()]])
# Out:
# Weight coefficients:  [[-6.25100323]]
# y-axis intercept:  [1879.14994975]

# %%
y_min = model.predict(x_min)
y_max = model.predict(x_max)

# %%
plt.scatter(x, y, c='blue')
plt.plot([x_min[0], x_max[0]], [y_min[0], y_max[0]], c='red')

# %%
predicted = model.predict(x)
mse = mean_squared_error(y, predicted)
r2 = r2_score(y, predicted)

print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2 ): {r2}")
# Out:
# Mean Squared Error (MSE): 524408.5356104248
# R-squared (R2 ): 0.11856032210588108

# %%
model.score(x, y)
# Out:
# 0.11856032210588108

# %%
x_train, x_test, y_train, y_test = train_test_split(x, y, random_state=44)

# %%
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
model.score(x_test, y_test)
# Out:
# 0.21885520022562754

# %%
plt.scatter(predicted, predicted - y)
plt.hlines(y=0, xmin=predicted.min(), xmax=predicted.max())
plt.show()
